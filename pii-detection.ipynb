# %%
# %%capture
# !pip install -U -q presidio_analyzer --no-index --find-links=file:///kaggle/input/presidio-wheels/presidio

# %%
import json
import re

import pandas as pd
import polars as pl
from tqdm import tqdm
from dateutil import parser

from presidio_analyzer.recognizer_registry import RecognizerRegistry
from presidio_analyzer.context_aware_enhancers import LemmaContextAwareEnhancer
from presidio_analyzer.nlp_engine import NlpEngineProvider
from presidio_analyzer import AnalyzerEngine, PatternRecognizer, Pattern

pl.Config.set_tbl_cols(-1)
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_tbl_rows(100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
train_df = json.load(open("/kaggle/input/pii-detection-removal-from-educational-data/train.json"))
test_df = json.load(open('/kaggle/input/pii-detection-removal-from-educational-data/test.json'))
print(f"Length of train data: {len(train_df)}, keys: {train_df[0].keys()}")
print("-" * 100)
labels = set()
for i in range(len(train_df)):
    labels.update(train_df[i]['labels'])
print(f"Data labels: {labels}")
# Out:
# Length of train data: 6807, keys: dict_keys(['document', 'full_text', 'tokens', 'trailing_whitespace', 'labels'])
# ----------------------------------------------------------------------------------------------------
# Data labels: {'B-STREET_ADDRESS', 'B-URL_PERSONAL', 'B-EMAIL', 'I-URL_PERSONAL', 'B-PHONE_NUM', 'B-ID_NUM', 'B-NAME_STUDENT', 'I-NAME_STUDENT', 'B-USERNAME', 'I-PHONE_NUM', 'O', 'I-ID_NUM', 'I-STREET_ADDRESS'}

# %%
df_train = pl.read_json('/kaggle/input/pii-detection-removal-from-educational-data/train.json')
df_test = pl.read_json('/kaggle/input/pii-detection-removal-from-educational-data/test.json')
df_sample_submission = pl.read_csv('/kaggle/input/pii-detection-removal-from-educational-data/sample_submission.csv')

# %%
df_train_exploded = df_train.select('tokens', 'trailing_whitespace', 'labels').explode(pl.all())

# %%
for label in labels:
    display(df_train_exploded.filter(pl.col('labels') == label))
# Out:
# shape: (2, 3)
# ┌────────┬─────────────────────┬──────────────────┐
# │ tokens ┆ trailing_whitespace ┆ labels           │
# │ ---    ┆ ---                 ┆ ---              │
# │ str    ┆ bool                ┆ str              │
# ╞════════╪═════════════════════╪══════════════════╡
# │ 591    ┆ true                ┆ B-STREET_ADDRESS │
# │ 743    ┆ true                ┆ B-STREET_ADDRESS │
# └────────┴─────────────────────┴──────────────────┘
# shape: (110, 3)
# ┌───────────────────────────────────────────────────────────┬─────────────────────┬────────────────┐
# │ tokens                                                    ┆ trailing_whitespace ┆ labels         │
# │ ---                                                       ┆ ---                 ┆ ---            │
# │ str                                                       ┆ bool                ┆ str            │
# ╞═══════════════════════════════════════════════════════════╪═════════════════════╪════════════════╡
# │ https://www.jackson.com/list/explorehomepage.htm          ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.linkedin.com/in/mmartinez                     ┆ true                ┆ B-URL_PERSONAL │
# │ https://youtu.be/rFD2lJuvace                              ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.hall.biz/wp-contenthome.html                  ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.burns-lopez.com/categories/appabout.asp        ┆ false               ┆ B-URL_PERSONAL │
# │ http://jacobs-fisher.com/listpost.html                    ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=n-ajTPJ1h-J               ┆ false               ┆ B-URL_PERSONAL │
# │ tps://www.facebook.com/bclark                             ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/channel/UC1ElAcppeuhfet           ┆ true                ┆ B-URL_PERSONAL │
# │ https://oconnell-townsend.com/wp-content/categorieshomepa ┆ false               ┆ B-URL_PERSONAL │
# │ ge.html                                                   ┆                     ┆                │
# │ https://www.peterson.net/tag/app/listmain.php             ┆ false               ┆ B-URL_PERSONAL │
# │ https://diaz.com/tag/wp-contentlogin.htm                  ┆ false               ┆ B-URL_PERSONAL │
# │ https://diaz.com/tag/wp-contentlogin.htm                  ┆ false               ┆ B-URL_PERSONAL │
# │ https://diaz.com/tag/wp-contentlogin.htm                  ┆ false               ┆ B-URL_PERSONAL │
# │ https://diaz.com/tag/wp-contentlogin.htm                  ┆ false               ┆ B-URL_PERSONAL │
# │ http://hodge-ramsey.com/tagmain.html                      ┆ true                ┆ B-URL_PERSONAL │
# │ http://jones-mendoza.com/blog/search/searchprivacy.php    ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.kramer.info/wp-content/category/bloghome.php  ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.chambers.com/wp-content/app/categorieshomepage ┆ false               ┆ B-URL_PERSONAL │
# │ .jsp                                                      ┆                     ┆                │
# │ http://chang.com/tagspost.asp                             ┆ false               ┆ B-URL_PERSONAL │
# │ https://jones-hernandez.com/main/tag/listindex.htm        ┆ false               ┆ B-URL_PERSONAL │
# │ https://jones-hernandez.com/main/tag/listindex.htm        ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=2sOzgGAeiQV               ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.miller.org/search/tags/tagsearch.php           ┆ false               ┆ B-URL_PERSONAL │
# │ http://mcneil.org/list/taghomepage.htm                    ┆ false               ┆ B-URL_PERSONAL │
# │ http://mcneil.org/list/taghomepage.htm                    ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=e2D2mFcZzeW               ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=EnVUhYZvCFr               ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=tQSdE32O5KE               ┆ false               ┆ B-URL_PERSONAL │
# │ http://mcdonald-pope.com/categorycategory.jsp             ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.hart.com/posts/tagspost.htm                   ┆ false               ┆ B-URL_PERSONAL │
# │ https://soto.com/listregister.asp                         ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.linkedin.com/in/michael16                     ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.frederick-curtis.net/posts/wp-content/category ┆ false               ┆ B-URL_PERSONAL │
# │ author.php                                                ┆                     ┆                │
# │ https://ingram-castro.com/tagsmain.html                   ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.facebook.com/amanda37                         ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.facebook.com/amanda37                         ┆ false               ┆ B-URL_PERSONAL │
# │ https://jones.com/tags/wp-contentpost.html                ┆ true                ┆ B-URL_PERSONAL │
# │ http://www.tate.com/                                      ┆ true                ┆ B-URL_PERSONAL │
# │ http://www.melendez.biz/postsabout.html                   ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.cuevas.info/blogsearch.html                   ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.linkedin.com/pulmarkkelly                     ┆ false               ┆ B-URL_PERSONAL │
# │ https://howell-brooks.com/wp-content/mainprivacy.htm      ┆ false               ┆ B-URL_PERSONAL │
# │ http://moore.com/explore/tagterms.php                     ┆ false               ┆ B-URL_PERSONAL │
# │ http://martin.com/app/tags/searchregister.php             ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.fitzgerald-nicholson.com/search/categories/wp ┆ false               ┆ B-URL_PERSONAL │
# │ -contentlogin.htm                                         ┆                     ┆                │
# │ https://vargas.com/list/exploreauthor.html                ┆ false               ┆ B-URL_PERSONAL │
# │ https://youtu.be/bDPejFHJSsT                              ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.park-baker.com/tags/explore/blogpost.php      ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/user/vdrake                       ┆ false               ┆ B-URL_PERSONAL │
# │ …                                                         ┆ …                   ┆ …              │
# │ https://www.brooks.net/exploreprivacy.html                ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=tIBN9VJ0S4a               ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.smith-flores.com/mainlogin.htm                ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.jackson.com/categories/search/tagsmain.html    ┆ false               ┆ B-URL_PERSONAL │
# │ http://fisher.com/category/wp-contentregister.htm         ┆ false               ┆ B-URL_PERSONAL │
# │ https://youtu.be/h9YTxzr_HPS                              ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=2W2A1l98qVg               ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=B131Tm9Iex1               ┆ false               ┆ B-URL_PERSONAL │
# │ http://beck-calhoun.biz/bloghome.jsp                      ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.chapman-robinson.com/explorelogin.htm          ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.green.info/wp-content/wp-contentpost.html      ┆ true                ┆ B-URL_PERSONAL │
# │ http://www.olsen.org/posts/blog/searchabout.html          ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.clark-winters.com/tag/searchauthor.html       ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.barry.com/main/list/postshomepage.html         ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.shaw-smith.net/tags/listfaq.html              ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.bonilla.org/category/tags/wp-contentfaq.htm    ┆ false               ┆ B-URL_PERSONAL │
# │ https://butler.com/search/wp-content/categorypost.jsp     ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.price.info/categories/search/tagprivacy.htm   ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.price.info/categories/search/tagprivacy.htm   ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.facebook.com/pamela23                         ┆ true                ┆ B-URL_PERSONAL │
# │ https://buck-flores.com/list/postshomepage.jsp            ┆ true                ┆ B-URL_PERSONAL │
# │ http://hogan.com/app/categoriesindex.php                  ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.rice-trevino.org/tag/blogindex.asp            ┆ true                ┆ B-URL_PERSONAL │
# │ http://camacho.biz/blog/main/appfaq.jsp                   ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.daniels.biz/tagssearch.php                     ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.stokes.com/wp-content/main/searchregister.htm  ┆ false               ┆ B-URL_PERSONAL │
# │ http://osborne.org/main/posts/tagprivacy.asp              ┆ false               ┆ B-URL_PERSONAL │
# │ http://thomas.biz/list/taghome.php                        ┆ false               ┆ B-URL_PERSONAL │
# │ http://www.johnson.com/categories/wp-content/tagabout.htm ┆ false               ┆ B-URL_PERSONAL │
# │ l                                                         ┆                     ┆                │
# │ http://www.jackson.com/appcategory.html                   ┆ false               ┆ B-URL_PERSONAL │
# │ https://youtu.be/1pM3sb7AMPs                              ┆ false               ┆ B-URL_PERSONAL │
# │ https://glenn.org/postsindex.jsp                          ┆ false               ┆ B-URL_PERSONAL │
# │ https://youtu.be/Kb-hqNGr5lJ                              ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.johnson.biz/wp-content/appcategory.php        ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.johnson.biz/wp-content/appcategory.php        ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=x5Y6nYsYmtA               ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.youtube.com/watch?v=jhw3sb6ZCAZ               ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.lopez.com/category/tagprivacy.php             ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.campbell-silva.org/app/tagsauthor.html        ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.linkedin.com/feevanessacook                   ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.williamson.net/wp-contentcategory.php         ┆ false               ┆ B-URL_PERSONAL │
# │ https://hernandez.com/exploremain.html                    ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.roman.info/list/appindex.html                 ┆ true                ┆ B-URL_PERSONAL │
# │ https://hernandez.com/exploremain.html                    ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.roman.info/list/appindex.html                 ┆ false               ┆ B-URL_PERSONAL │
# │ https://hernandez.com/exploremain.html                    ┆ true                ┆ B-URL_PERSONAL │
# │ https://www.roman.info/list/appindex.html                 ┆ true                ┆ B-URL_PERSONAL │
# │ https://hernandez.com/exploremain.html                    ┆ false               ┆ B-URL_PERSONAL │
# │ https://www.roman.info/list/appindex.html                 ┆ false               ┆ B-URL_PERSONAL │
# │ https://alvarado.com/categoriesindex.html                 ┆ false               ┆ B-URL_PERSONAL │
# └───────────────────────────────────────────────────────────┴─────────────────────┴────────────────┘
# shape: (39, 3)
# ┌──────────────────────────┬─────────────────────┬─────────┐
# │ tokens                   ┆ trailing_whitespace ┆ labels  │
# │ ---                      ┆ ---                 ┆ ---     │
# │ str                      ┆ bool                ┆ str     │
# ╞══════════════════════════╪═════════════════════╪═════════╡
# │ djones@gmail.com         ┆ true                ┆ B-EMAIL │
# │ matthew72@hotmail.com    ┆ false               ┆ B-EMAIL │
# │ belindarojas@yahoo.com   ┆ true                ┆ B-EMAIL │
# │ kennethevans@hotmail.com ┆ false               ┆ B-EMAIL │
# │ agood@gmail.com          ┆ false               ┆ B-EMAIL │
# │ agood@gmail.com          ┆ false               ┆ B-EMAIL │
# │ hwillis@gmail.com        ┆ true                ┆ B-EMAIL │
# │ kellyharrison@gmail.com  ┆ true                ┆ B-EMAIL │
# │ kellyharrison@gmail.com  ┆ true                ┆ B-EMAIL │
# │ lowetyler@hotmail.com    ┆ false               ┆ B-EMAIL │
# │ murraythomas@gmail.com   ┆ false               ┆ B-EMAIL │
# │ vmartinez@hotmail.com    ┆ false               ┆ B-EMAIL │
# │ sheena82@yahoo.com       ┆ false               ┆ B-EMAIL │
# │ nbarker@hotmail.com      ┆ true                ┆ B-EMAIL │
# │ nbarker@hotmail.com      ┆ true                ┆ B-EMAIL │
# │ nbarker@hotmail.com      ┆ true                ┆ B-EMAIL │
# │ johnsondavid@hotmail.com ┆ false               ┆ B-EMAIL │
# │ johnsondavid@hotmail.com ┆ false               ┆ B-EMAIL │
# │ catherine19@hotmail.com  ┆ false               ┆ B-EMAIL │
# │ john03@yahoo.com         ┆ false               ┆ B-EMAIL │
# │ john03@yahoo.com         ┆ false               ┆ B-EMAIL │
# │ lisarose@gmail.com       ┆ false               ┆ B-EMAIL │
# │ diazkristen@gmail.com    ┆ false               ┆ B-EMAIL │
# │ lisarose@gmail.com       ┆ false               ┆ B-EMAIL │
# │ diazkristen@gmail.com    ┆ false               ┆ B-EMAIL │
# │ andrew58@gmail.com       ┆ false               ┆ B-EMAIL │
# │ boydcynthia@yahoo.com    ┆ true                ┆ B-EMAIL │
# │ laurie33@yahoo.com       ┆ false               ┆ B-EMAIL │
# │ laurie33@yahoo.com       ┆ false               ┆ B-EMAIL │
# │ pauljohnson@hotmail.com  ┆ false               ┆ B-EMAIL │
# │ pauljohnson@hotmail.com  ┆ false               ┆ B-EMAIL │
# │ jarviscindy@hotmail.com  ┆ false               ┆ B-EMAIL │
# │ jarviscindy@hotmail.com  ┆ false               ┆ B-EMAIL │
# │ jray@hotmail.com         ┆ false               ┆ B-EMAIL │
# │ gday@hotmail.com         ┆ true                ┆ B-EMAIL │
# │ gday@hotmail.com         ┆ false               ┆ B-EMAIL │
# │ gday@hotmail.com         ┆ true                ┆ B-EMAIL │
# │ noah14@hotmail.com       ┆ true                ┆ B-EMAIL │
# │ hbrown@yahoo.com         ┆ true                ┆ B-EMAIL │
# └──────────────────────────┴─────────────────────┴─────────┘
# shape: (1, 3)
# ┌───────────┬─────────────────────┬────────────────┐
# │ tokens    ┆ trailing_whitespace ┆ labels         │
# │ ---       ┆ ---                 ┆ ---            │
# │ str       ┆ bool                ┆ str            │
# ╞═══════════╪═════════════════════╪════════════════╡
# │ nYZqnhEXw ┆ false               ┆ I-URL_PERSONAL │
# └───────────┴─────────────────────┴────────────────┘
# shape: (6, 3)
# ┌──────────────┬─────────────────────┬─────────────┐
# │ tokens       ┆ trailing_whitespace ┆ labels      │
# │ ---          ┆ ---                 ┆ ---         │
# │ str          ┆ bool                ┆ str         │
# ╞══════════════╪═════════════════════╪═════════════╡
# │ (            ┆ false               ┆ B-PHONE_NUM │
# │ (            ┆ false               ┆ B-PHONE_NUM │
# │ (            ┆ false               ┆ B-PHONE_NUM │
# │ (            ┆ false               ┆ B-PHONE_NUM │
# │ (            ┆ false               ┆ B-PHONE_NUM │
# │ 410.526.1667 ┆ true                ┆ B-PHONE_NUM │
# └──────────────┴─────────────────────┴─────────────┘
# shape: (78, 3)
# ┌─────────────────────┬─────────────────────┬──────────┐
# │ tokens              ┆ trailing_whitespace ┆ labels   │
# │ ---                 ┆ ---                 ┆ ---      │
# │ str                 ┆ bool                ┆ str      │
# ╞═════════════════════╪═════════════════════╪══════════╡
# │ 860632713425        ┆ true                ┆ B-ID_NUM │
# │ 530670102508        ┆ true                ┆ B-ID_NUM │
# │ 530670102508        ┆ true                ┆ B-ID_NUM │
# │ 875673967537        ┆ true                ┆ B-ID_NUM │
# │ 860632713425        ┆ true                ┆ B-ID_NUM │
# │ 557349702179        ┆ true                ┆ B-ID_NUM │
# │ 784372734211        ┆ true                ┆ B-ID_NUM │
# │ 054176622314        ┆ true                ┆ B-ID_NUM │
# │ 674915248960        ┆ true                ┆ B-ID_NUM │
# │ 932353568953        ┆ true                ┆ B-ID_NUM │
# │ 982645662261        ┆ false               ┆ B-ID_NUM │
# │ 409046248321        ┆ false               ┆ B-ID_NUM │
# │ 163133980712        ┆ true                ┆ B-ID_NUM │
# │ 186941941714        ┆ false               ┆ B-ID_NUM │
# │ 159531167997        ┆ false               ┆ B-ID_NUM │
# │ 159531167997        ┆ true                ┆ B-ID_NUM │
# │ 046922558887        ┆ false               ┆ B-ID_NUM │
# │ 943063077874        ┆ false               ┆ B-ID_NUM │
# │ 792389774673        ┆ false               ┆ B-ID_NUM │
# │ 167695383458        ┆ false               ┆ B-ID_NUM │
# │ Iz.:999893751750    ┆ false               ┆ B-ID_NUM │
# │ Kl.:838901042770    ┆ false               ┆ B-ID_NUM │
# │ 06EYD876            ┆ false               ┆ B-ID_NUM │
# │ 143860010348        ┆ true                ┆ B-ID_NUM │
# │ Ei:556799175487     ┆ false               ┆ B-ID_NUM │
# │ 143860010348        ┆ true                ┆ B-ID_NUM │
# │ Un:705491035775     ┆ false               ┆ B-ID_NUM │
# │ 143860010348        ┆ true                ┆ B-ID_NUM │
# │ Kh:360595695159     ┆ false               ┆ B-ID_NUM │
# │ 143860010348        ┆ true                ┆ B-ID_NUM │
# │ Kh:217952887271     ┆ false               ┆ B-ID_NUM │
# │ 35615904922         ┆ false               ┆ B-ID_NUM │
# │ 696135165639        ┆ true                ┆ B-ID_NUM │
# │ Vw.:403489591437    ┆ false               ┆ B-ID_NUM │
# │ 141774671173        ┆ true                ┆ B-ID_NUM │
# │ 747051878431        ┆ false               ┆ B-ID_NUM │
# │ 779875708882        ┆ true                ┆ B-ID_NUM │
# │ 800306846075        ┆ true                ┆ B-ID_NUM │
# │ 955487471144        ┆ true                ┆ B-ID_NUM │
# │ 276795361801        ┆ false               ┆ B-ID_NUM │
# │ 276795361801        ┆ false               ┆ B-ID_NUM │
# │ 034626995785        ┆ false               ┆ B-ID_NUM │
# │ VZ:775Y6A5764       ┆ false               ┆ B-ID_NUM │
# │ DM:705244534902     ┆ false               ┆ B-ID_NUM │
# │ 132305666219        ┆ false               ┆ B-ID_NUM │
# │ 789323889085        ┆ false               ┆ B-ID_NUM │
# │ 762035863358        ┆ false               ┆ B-ID_NUM │
# │ 188408534931        ┆ true                ┆ B-ID_NUM │
# │ nMFtUVxSUI|33529258 ┆ false               ┆ B-ID_NUM │
# │ nMFtUVxSUI|33529258 ┆ false               ┆ B-ID_NUM │
# │ 51,00,23,0          ┆ true                ┆ B-ID_NUM │
# │ 342998677810        ┆ false               ┆ B-ID_NUM │
# │ 522233062166        ┆ true                ┆ B-ID_NUM │
# │ 843756944804        ┆ true                ┆ B-ID_NUM │
# │ 493950392533        ┆ true                ┆ B-ID_NUM │
# │ 183169291463        ┆ false               ┆ B-ID_NUM │
# │ 172801513686        ┆ false               ┆ B-ID_NUM │
# │ 172801513686        ┆ false               ┆ B-ID_NUM │
# │ 208798413907        ┆ false               ┆ B-ID_NUM │
# │ 347376430553        ┆ false               ┆ B-ID_NUM │
# │ 943995368223        ┆ false               ┆ B-ID_NUM │
# │ 027693              ┆ true                ┆ B-ID_NUM │
# │ ras21               ┆ false               ┆ B-ID_NUM │
# │ 723847538279        ┆ false               ┆ B-ID_NUM │
# │ 534516353860        ┆ false               ┆ B-ID_NUM │
# │ 871483046449        ┆ false               ┆ B-ID_NUM │
# │ 836172426340        ┆ false               ┆ B-ID_NUM │
# │ 369615882777        ┆ false               ┆ B-ID_NUM │
# │ 014674070485        ┆ false               ┆ B-ID_NUM │
# │ 264945858442        ┆ false               ┆ B-ID_NUM │
# │ 320622779078        ┆ false               ┆ B-ID_NUM │
# │ Weyhacy_7000693584  ┆ false               ┆ B-ID_NUM │
# │ 047378465           ┆ true                ┆ B-ID_NUM │
# │ 047378465           ┆ true                ┆ B-ID_NUM │
# │ IV-8322             ┆ true                ┆ B-ID_NUM │
# │ IV-8322             ┆ true                ┆ B-ID_NUM │
# │ Z.S.                ┆ true                ┆ B-ID_NUM │
# │ V69230              ┆ false               ┆ B-ID_NUM │
# └─────────────────────┴─────────────────────┴──────────┘
# shape: (1_365, 3)
# ┌────────────┬─────────────────────┬────────────────┐
# │ tokens     ┆ trailing_whitespace ┆ labels         │
# │ ---        ┆ ---                 ┆ ---            │
# │ str        ┆ bool                ┆ str            │
# ╞════════════╪═════════════════════╪════════════════╡
# │ Nathalie   ┆ true                ┆ B-NAME_STUDENT │
# │ Nathalie   ┆ true                ┆ B-NAME_STUDENT │
# │ Nathalie   ┆ true                ┆ B-NAME_STUDENT │
# │ Diego      ┆ true                ┆ B-NAME_STUDENT │
# │ Diego      ┆ true                ┆ B-NAME_STUDENT │
# │ Gilberto   ┆ true                ┆ B-NAME_STUDENT │
# │ Sindy      ┆ true                ┆ B-NAME_STUDENT │
# │ Nadine     ┆ true                ┆ B-NAME_STUDENT │
# │ Eladio     ┆ true                ┆ B-NAME_STUDENT │
# │ Silvia     ┆ true                ┆ B-NAME_STUDENT │
# │ Sakir      ┆ true                ┆ B-NAME_STUDENT │
# │ Francisco  ┆ true                ┆ B-NAME_STUDENT │
# │ Stefano    ┆ true                ┆ B-NAME_STUDENT │
# │ Al         ┆ false               ┆ B-NAME_STUDENT │
# │ Pepa       ┆ true                ┆ B-NAME_STUDENT │
# │ Deiby      ┆ false               ┆ B-NAME_STUDENT │
# │ Fareed     ┆ true                ┆ B-NAME_STUDENT │
# │ Claudia    ┆ true                ┆ B-NAME_STUDENT │
# │ Rajinder   ┆ true                ┆ B-NAME_STUDENT │
# │ Maud       ┆ true                ┆ B-NAME_STUDENT │
# │ Maud       ┆ true                ┆ B-NAME_STUDENT │
# │ Maud       ┆ true                ┆ B-NAME_STUDENT │
# │ Maud       ┆ true                ┆ B-NAME_STUDENT │
# │ Zia        ┆ false               ┆ B-NAME_STUDENT │
# │ Davide     ┆ true                ┆ B-NAME_STUDENT │
# │ Karan      ┆ true                ┆ B-NAME_STUDENT │
# │ Milton     ┆ true                ┆ B-NAME_STUDENT │
# │ Luis       ┆ true                ┆ B-NAME_STUDENT │
# │ Cesar      ┆ true                ┆ B-NAME_STUDENT │
# │ Dharmendra ┆ true                ┆ B-NAME_STUDENT │
# │ Dharmendra ┆ true                ┆ B-NAME_STUDENT │
# │ Daniel     ┆ false               ┆ B-NAME_STUDENT │
# │ Suhag      ┆ true                ┆ B-NAME_STUDENT │
# │ Eina       ┆ true                ┆ B-NAME_STUDENT │
# │ Mauro      ┆ true                ┆ B-NAME_STUDENT │
# │ Gabriel    ┆ true                ┆ B-NAME_STUDENT │
# │ Hlengiwe   ┆ true                ┆ B-NAME_STUDENT │
# │ Tino       ┆ true                ┆ B-NAME_STUDENT │
# │ Tino       ┆ true                ┆ B-NAME_STUDENT │
# │ Swetha     ┆ true                ┆ B-NAME_STUDENT │
# │ Alex       ┆ true                ┆ B-NAME_STUDENT │
# │ Alex       ┆ true                ┆ B-NAME_STUDENT │
# │ Tino       ┆ true                ┆ B-NAME_STUDENT │
# │ Hlengiwe   ┆ true                ┆ B-NAME_STUDENT │
# │ Mohd       ┆ true                ┆ B-NAME_STUDENT │
# │ Wilson     ┆ true                ┆ B-NAME_STUDENT │
# │ Wilson     ┆ true                ┆ B-NAME_STUDENT │
# │ Madina     ┆ true                ┆ B-NAME_STUDENT │
# │ Amparo     ┆ false               ┆ B-NAME_STUDENT │
# │ Edgar      ┆ true                ┆ B-NAME_STUDENT │
# │ …          ┆ …                   ┆ …              │
# │ Rolando    ┆ true                ┆ B-NAME_STUDENT │
# │ Junior     ┆ true                ┆ B-NAME_STUDENT │
# │ Junior     ┆ true                ┆ B-NAME_STUDENT │
# │ Andreas    ┆ true                ┆ B-NAME_STUDENT │
# │ Mike       ┆ true                ┆ B-NAME_STUDENT │
# │ Sarah      ┆ true                ┆ B-NAME_STUDENT │
# │ Sarah      ┆ true                ┆ B-NAME_STUDENT │
# │ Adem       ┆ true                ┆ B-NAME_STUDENT │
# │ Federico   ┆ true                ┆ B-NAME_STUDENT │
# │ Barbie     ┆ true                ┆ B-NAME_STUDENT │
# │ Maria      ┆ true                ┆ B-NAME_STUDENT │
# │ Cassie     ┆ true                ┆ B-NAME_STUDENT │
# │ Erika      ┆ true                ┆ B-NAME_STUDENT │
# │ Karen      ┆ true                ┆ B-NAME_STUDENT │
# │ Ana        ┆ true                ┆ B-NAME_STUDENT │
# │ Benjamin   ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ false               ┆ B-NAME_STUDENT │
# │ David      ┆ false               ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ false               ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ false               ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ false               ┆ B-NAME_STUDENT │
# │ David      ┆ true                ┆ B-NAME_STUDENT │
# │ David      ┆ false               ┆ B-NAME_STUDENT │
# │ David      ┆ false               ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ true                ┆ B-NAME_STUDENT │
# │ Cristiane  ┆ false               ┆ B-NAME_STUDENT │
# │ David      ┆ false               ┆ B-NAME_STUDENT │
# │ Alina      ┆ true                ┆ B-NAME_STUDENT │
# │ Hersh      ┆ true                ┆ B-NAME_STUDENT │
# │ Robert     ┆ true                ┆ B-NAME_STUDENT │
# │ Said       ┆ true                ┆ B-NAME_STUDENT │
# │ Brittany   ┆ true                ┆ B-NAME_STUDENT │
# │ Gopal      ┆ true                ┆ B-NAME_STUDENT │
# │ Jose       ┆ true                ┆ B-NAME_STUDENT │
# │ Jose       ┆ true                ┆ B-NAME_STUDENT │
# │ Oscar      ┆ false               ┆ B-NAME_STUDENT │
# │ Silvia     ┆ true                ┆ B-NAME_STUDENT │
# │ Carlos     ┆ true                ┆ B-NAME_STUDENT │
# │ Carlos     ┆ true                ┆ B-NAME_STUDENT │
# └────────────┴─────────────────────┴────────────────┘
# shape: (1_096, 3)
# ┌──────────────┬─────────────────────┬────────────────┐
# │ tokens       ┆ trailing_whitespace ┆ labels         │
# │ ---          ┆ ---                 ┆ ---            │
# │ str          ┆ bool                ┆ str            │
# ╞══════════════╪═════════════════════╪════════════════╡
# │ Sylla        ┆ false               ┆ I-NAME_STUDENT │
# │ Sylla        ┆ false               ┆ I-NAME_STUDENT │
# │ Sylla        ┆ false               ┆ I-NAME_STUDENT │
# │ Estrada      ┆ false               ┆ I-NAME_STUDENT │
# │ Estrada      ┆ false               ┆ I-NAME_STUDENT │
# │ Gamboa       ┆ false               ┆ I-NAME_STUDENT │
# │ Samaca       ┆ false               ┆ I-NAME_STUDENT │
# │ Born         ┆ false               ┆ I-NAME_STUDENT │
# │ Amaya        ┆ false               ┆ I-NAME_STUDENT │
# │ Villalobos   ┆ false               ┆ I-NAME_STUDENT │
# │ Ahmad        ┆ false               ┆ I-NAME_STUDENT │
# │ Ferreira     ┆ false               ┆ I-NAME_STUDENT │
# │ Lovato       ┆ false               ┆ I-NAME_STUDENT │
# │ Medrano      ┆ false               ┆ I-NAME_STUDENT │
# │ Ponce        ┆ false               ┆ I-NAME_STUDENT │
# │ Sarria       ┆ false               ┆ I-NAME_STUDENT │
# │ Santos       ┆ true                ┆ I-NAME_STUDENT │
# │ Dias         ┆ false               ┆ I-NAME_STUDENT │
# │ Dias         ┆ false               ┆ I-NAME_STUDENT │
# │ Dias         ┆ false               ┆ I-NAME_STUDENT │
# │ Dias         ┆ false               ┆ I-NAME_STUDENT │
# │ Carletti     ┆ false               ┆ I-NAME_STUDENT │
# │ Patel        ┆ false               ┆ I-NAME_STUDENT │
# │ Desai        ┆ false               ┆ I-NAME_STUDENT │
# │ Ramadan      ┆ false               ┆ I-NAME_STUDENT │
# │ Rivera       ┆ false               ┆ I-NAME_STUDENT │
# │ Asiri        ┆ true                ┆ I-NAME_STUDENT │
# │ Asiri        ┆ true                ┆ I-NAME_STUDENT │
# │ Shah         ┆ false               ┆ I-NAME_STUDENT │
# │ Nazim        ┆ false               ┆ I-NAME_STUDENT │
# │ Pacheco      ┆ false               ┆ I-NAME_STUDENT │
# │ Bravo        ┆ true                ┆ I-NAME_STUDENT │
# │ Swetha       ┆ true                ┆ I-NAME_STUDENT │
# │ Swetha       ┆ true                ┆ I-NAME_STUDENT │
# │ Lopez        ┆ true                ┆ I-NAME_STUDENT │
# │ Swetha       ┆ true                ┆ I-NAME_STUDENT │
# │ Swetha       ┆ true                ┆ I-NAME_STUDENT │
# │ Bravo        ┆ true                ┆ I-NAME_STUDENT │
# │ Lopez        ┆ true                ┆ I-NAME_STUDENT │
# │ Asim         ┆ false               ┆ I-NAME_STUDENT │
# │ Syafinaz     ┆ true                ┆ I-NAME_STUDENT │
# │ Syafinaz     ┆ true                ┆ I-NAME_STUDENT │
# │ Eno          ┆ false               ┆ I-NAME_STUDENT │
# │ Lara         ┆ false               ┆ I-NAME_STUDENT │
# │ Saeed        ┆ false               ┆ I-NAME_STUDENT │
# │ Saeed        ┆ false               ┆ I-NAME_STUDENT │
# │ Saeed        ┆ false               ┆ I-NAME_STUDENT │
# │ Courtois     ┆ false               ┆ I-NAME_STUDENT │
# │ Vazquez      ┆ true                ┆ I-NAME_STUDENT │
# │ Msibi        ┆ false               ┆ I-NAME_STUDENT │
# │ …            ┆ …                   ┆ …              │
# │ Fong         ┆ false               ┆ I-NAME_STUDENT │
# │ Fong         ┆ true                ┆ I-NAME_STUDENT │
# │ Adamo        ┆ false               ┆ I-NAME_STUDENT │
# │ Gonzalez     ┆ false               ┆ I-NAME_STUDENT │
# │ Paswan       ┆ false               ┆ I-NAME_STUDENT │
# │ Robinson     ┆ true                ┆ I-NAME_STUDENT │
# │ Rodriguez    ┆ false               ┆ I-NAME_STUDENT │
# │ Tan          ┆ true                ┆ I-NAME_STUDENT │
# │ Buonincontro ┆ false               ┆ I-NAME_STUDENT │
# │ Rosa         ┆ false               ┆ I-NAME_STUDENT │
# │ Rosa         ┆ false               ┆ I-NAME_STUDENT │
# │ Rosa         ┆ false               ┆ I-NAME_STUDENT │
# │ Garcia       ┆ false               ┆ I-NAME_STUDENT │
# │ Garcia       ┆ false               ┆ I-NAME_STUDENT │
# │ Luis         ┆ true                ┆ I-NAME_STUDENT │
# │ Czarnecka    ┆ false               ┆ I-NAME_STUDENT │
# │ Vanegas      ┆ false               ┆ I-NAME_STUDENT │
# │ Sanna        ┆ false               ┆ I-NAME_STUDENT │
# │ Obrien       ┆ false               ┆ I-NAME_STUDENT │
# │ Salazar      ┆ false               ┆ I-NAME_STUDENT │
# │ Ben          ┆ false               ┆ I-NAME_STUDENT │
# │ Martinez     ┆ false               ┆ I-NAME_STUDENT │
# │ Wallace      ┆ true                ┆ I-NAME_STUDENT │
# │ Wallace      ┆ true                ┆ I-NAME_STUDENT │
# │ Jensen       ┆ false               ┆ I-NAME_STUDENT │
# │ Rodriguez    ┆ false               ┆ I-NAME_STUDENT │
# │ Roberto      ┆ false               ┆ I-NAME_STUDENT │
# │ Roberto      ┆ false               ┆ I-NAME_STUDENT │
# │ Moka         ┆ false               ┆ I-NAME_STUDENT │
# │ Ragni        ┆ false               ┆ I-NAME_STUDENT │
# │ Refaat       ┆ false               ┆ I-NAME_STUDENT │
# │ Quispe       ┆ false               ┆ I-NAME_STUDENT │
# │ Viera        ┆ false               ┆ I-NAME_STUDENT │
# │ Taborda      ┆ true                ┆ I-NAME_STUDENT │
# │ Gardner      ┆ false               ┆ I-NAME_STUDENT │
# │ Gonzalez     ┆ false               ┆ I-NAME_STUDENT │
# │ Miller       ┆ true                ┆ I-NAME_STUDENT │
# │ Ijaz         ┆ false               ┆ I-NAME_STUDENT │
# │ Guerrero     ┆ false               ┆ I-NAME_STUDENT │
# │ Walsh        ┆ false               ┆ I-NAME_STUDENT │
# │ Catania      ┆ false               ┆ I-NAME_STUDENT │
# │ Jackson      ┆ false               ┆ I-NAME_STUDENT │
# │ Kumar        ┆ true                ┆ I-NAME_STUDENT │
# │ Luis         ┆ true                ┆ I-NAME_STUDENT │
# │ Llamas       ┆ false               ┆ I-NAME_STUDENT │
# │ Luis         ┆ true                ┆ I-NAME_STUDENT │
# │ Llamas       ┆ false               ┆ I-NAME_STUDENT │
# │ Cervantes    ┆ false               ┆ I-NAME_STUDENT │
# │ Hernandez    ┆ false               ┆ I-NAME_STUDENT │
# │ Hernandez    ┆ false               ┆ I-NAME_STUDENT │
# └──────────────┴─────────────────────┴────────────────┘
# shape: (6, 3)
# ┌──────────────────┬─────────────────────┬────────────┐
# │ tokens           ┆ trailing_whitespace ┆ labels     │
# │ ---              ┆ ---                 ┆ ---        │
# │ str              ┆ bool                ┆ str        │
# ╞══════════════════╪═════════════════════╪════════════╡
# │ castanedagabriel ┆ true                ┆ B-USERNAME │
# │ fdixon           ┆ true                ┆ B-USERNAME │
# │ fdixon           ┆ true                ┆ B-USERNAME │
# │ meyermichelle    ┆ false               ┆ B-USERNAME │
# │ jacob59          ┆ false               ┆ B-USERNAME │
# │ holmespatrick    ┆ false               ┆ B-USERNAME │
# └──────────────────┴─────────────────────┴────────────┘
# shape: (15, 3)
# ┌────────────┬─────────────────────┬─────────────┐
# │ tokens     ┆ trailing_whitespace ┆ labels      │
# │ ---        ┆ ---                 ┆ ---         │
# │ str        ┆ bool                ┆ str         │
# ╞════════════╪═════════════════════╪═════════════╡
# │ 320)202    ┆ false               ┆ I-PHONE_NUM │
# │ -          ┆ false               ┆ I-PHONE_NUM │
# │ 0688x95843 ┆ true                ┆ I-PHONE_NUM │
# │ 223)392    ┆ false               ┆ I-PHONE_NUM │
# │ -          ┆ false               ┆ I-PHONE_NUM │
# │ 2765       ┆ false               ┆ I-PHONE_NUM │
# │ 820)913    ┆ false               ┆ I-PHONE_NUM │
# │ -          ┆ false               ┆ I-PHONE_NUM │
# │ 3241x894   ┆ false               ┆ I-PHONE_NUM │
# │ 820)913    ┆ false               ┆ I-PHONE_NUM │
# │ -          ┆ false               ┆ I-PHONE_NUM │
# │ 3241x894   ┆ false               ┆ I-PHONE_NUM │
# │ 820)913    ┆ false               ┆ I-PHONE_NUM │
# │ -          ┆ false               ┆ I-PHONE_NUM │
# │ 3241x894   ┆ false               ┆ I-PHONE_NUM │
# └────────────┴─────────────────────┴─────────────┘
# shape: (4_989_794, 3)
# ┌──────────────┬─────────────────────┬────────┐
# │ tokens       ┆ trailing_whitespace ┆ labels │
# │ ---          ┆ ---                 ┆ ---    │
# │ str          ┆ bool                ┆ str    │
# ╞══════════════╪═════════════════════╪════════╡
# │ Design       ┆ true                ┆ O      │
# │ Thinking     ┆ true                ┆ O      │
# │ for          ┆ true                ┆ O      │
# │ innovation   ┆ true                ┆ O      │
# │ reflexion    ┆ false               ┆ O      │
# │ -            ┆ false               ┆ O      │
# │ Avril        ┆ true                ┆ O      │
# │ 2021         ┆ false               ┆ O      │
# │ -            ┆ false               ┆ O      │
# │              ┆ false               ┆ O      │
# │              ┆                     ┆        │
# │              ┆                     ┆        │
# │ Challenge    ┆ true                ┆ O      │
# │ &            ┆ true                ┆ O      │
# │ selection    ┆ false               ┆ O      │
# │              ┆ false               ┆ O      │
# │              ┆                     ┆        │
# │              ┆                     ┆        │
# │ The          ┆ true                ┆ O      │
# │ tool         ┆ true                ┆ O      │
# │ I            ┆ true                ┆ O      │
# │ use          ┆ true                ┆ O      │
# │ to           ┆ true                ┆ O      │
# │ help         ┆ true                ┆ O      │
# │ all          ┆ true                ┆ O      │
# │ stakeholders ┆ true                ┆ O      │
# │ finding      ┆ true                ┆ O      │
# │ their        ┆ true                ┆ O      │
# │ way          ┆ true                ┆ O      │
# │ through      ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ complexity   ┆ true                ┆ O      │
# │ of           ┆ true                ┆ O      │
# │ a            ┆ true                ┆ O      │
# │ project      ┆ true                ┆ O      │
# │ is           ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │              ┆ false               ┆ O      │
# │ mind         ┆ true                ┆ O      │
# │ map          ┆ false               ┆ O      │
# │ .            ┆ false               ┆ O      │
# │              ┆ false               ┆ O      │
# │              ┆                     ┆        │
# │              ┆                     ┆        │
# │ What         ┆ true                ┆ O      │
# │ exactly      ┆ true                ┆ O      │
# │ is           ┆ true                ┆ O      │
# │ a            ┆ true                ┆ O      │
# │ mind         ┆ true                ┆ O      │
# │ map          ┆ false               ┆ O      │
# │ ?            ┆ true                ┆ O      │
# │ According    ┆ true                ┆ O      │
# │ to           ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ definition   ┆ true                ┆ O      │
# │ of           ┆ true                ┆ O      │
# │ …            ┆ …                   ┆ …      │
# │ of           ┆ true                ┆ O      │
# │ a            ┆ true                ┆ O      │
# │ successful   ┆ true                ┆ O      │
# │ manager      ┆ true                ┆ O      │
# │ or           ┆ true                ┆ O      │
# │ a            ┆ true                ┆ O      │
# │ happy        ┆ true                ┆ O      │
# │ family       ┆ true                ┆ O      │
# │ would        ┆ true                ┆ O      │
# │ be           ┆ true                ┆ O      │
# │ shown        ┆ false               ┆ O      │
# │ ,            ┆ true                ┆ O      │
# │ in           ┆ true                ┆ O      │
# │ order        ┆ true                ┆ O      │
# │ to           ┆ true                ┆ O      │
# │ see          ┆ true                ┆ O      │
# │ which        ┆ true                ┆ O      │
# │ result       ┆ true                ┆ O      │
# │              ┆ false               ┆ O      │
# │ more         ┆ true                ┆ O      │
# │ attractive   ┆ true                ┆ O      │
# │ for          ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ candidates   ┆ true                ┆ O      │
# │ and          ┆ true                ┆ O      │
# │ conclusions  ┆ true                ┆ O      │
# │ would        ┆ true                ┆ O      │
# │ be           ┆ true                ┆ O      │
# │ drawn        ┆ true                ┆ O      │
# │ by           ┆ true                ┆ O      │
# │ stating      ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ factors      ┆ true                ┆ O      │
# │ determining  ┆ true                ┆ O      │
# │              ┆ false               ┆ O      │
# │ wellbeing    ┆ true                ┆ O      │
# │ mentioned    ┆ true                ┆ O      │
# │ before       ┆ false               ┆ O      │
# │ ,            ┆ true                ┆ O      │
# │ representing ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ opposite     ┆ true                ┆ O      │
# │ order        ┆ true                ┆ O      │
# │ of           ┆ true                ┆ O      │
# │ the          ┆ true                ┆ O      │
# │ process      ┆ true                ┆ O      │
# │ explained    ┆ true                ┆ O      │
# │ above        ┆ false               ┆ O      │
# │ .            ┆ false               ┆ O      │
# │              ┆ false               ┆ O      │
# │              ┆                     ┆        │
# │              ┆                     ┆        │
# └──────────────┴─────────────────────┴────────┘
# shape: (1, 3)
# ┌──────────┬─────────────────────┬──────────┐
# │ tokens   ┆ trailing_whitespace ┆ labels   │
# │ ---      ┆ ---                 ┆ ---      │
# │ str      ┆ bool                ┆ str      │
# ╞══════════╪═════════════════════╪══════════╡
# │ 30407059 ┆ false               ┆ I-ID_NUM │
# └──────────┴─────────────────────┴──────────┘
# shape: (20, 3)
# ┌─────────────┬─────────────────────┬──────────────────┐
# │ tokens      ┆ trailing_whitespace ┆ labels           │
# │ ---         ┆ ---                 ┆ ---              │
# │ str         ┆ bool                ┆ str              │
# ╞═════════════╪═════════════════════╪══════════════════╡
# │ Smith       ┆ true                ┆ I-STREET_ADDRESS │
# │ Centers     ┆ true                ┆ I-STREET_ADDRESS │
# │ Apt         ┆ false               ┆ I-STREET_ADDRESS │
# │ .           ┆ true                ┆ I-STREET_ADDRESS │
# │ 656         ┆ false               ┆ I-STREET_ADDRESS │
# │             ┆ false               ┆ I-STREET_ADDRESS │
# │             ┆                     ┆                  │
# │ Joshuamouth ┆ false               ┆ I-STREET_ADDRESS │
# │ ,           ┆ true                ┆ I-STREET_ADDRESS │
# │ RI          ┆ true                ┆ I-STREET_ADDRESS │
# │ 95963       ┆ true                ┆ I-STREET_ADDRESS │
# │ Erika       ┆ true                ┆ I-STREET_ADDRESS │
# │ Bypass      ┆ true                ┆ I-STREET_ADDRESS │
# │ Apt         ┆ false               ┆ I-STREET_ADDRESS │
# │ .           ┆ true                ┆ I-STREET_ADDRESS │
# │ 419         ┆ false               ┆ I-STREET_ADDRESS │
# │             ┆ false               ┆ I-STREET_ADDRESS │
# │             ┆                     ┆                  │
# │ Andreahaven ┆ false               ┆ I-STREET_ADDRESS │
# │ ,           ┆ true                ┆ I-STREET_ADDRESS │
# │ IL          ┆ true                ┆ I-STREET_ADDRESS │
# │ 54207       ┆ false               ┆ I-STREET_ADDRESS │
# └─────────────┴─────────────────────┴──────────────────┘

# %%
nlp_config = {
    "nlp_engine_name": "spacy",
    "models": [{"lang_code": "en", "model_name": "en_core_web_lg"}],
}

# %%
# NLP engine
provider = NlpEngineProvider(nlp_configuration=nlp_config)
nlp_engine = provider.create_engine()

# Address recognizer
address_regex = r'\b\d+\s+\w+(\s+\w+)*\s+((st(\.)?)|(ave(\.)?)|(rd(\.)?)|(blvd(\.)?)|(ln(\.)?)|(ct(\.)?)|(dr(\.)?))\b'
address_pattern = Pattern(name="address", regex=address_regex, score=0.5)
address_recognizer = PatternRecognizer(supported_entity="ADDRESS_CUSTOM",
                                       patterns=[address_pattern], context=["st", "Apt"])

# Email recognizer 
email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
email_pattern = Pattern(name="email address", regex=email_regex, score=0.5)
email_recognizer = PatternRecognizer(supported_entity="EMAIL_CUSTOM",
                                     patterns=[email_pattern])

# URL recognizer 
url_regex = "https?://\S+|www\.\S+"
url_pattern = Pattern(name="url", regex=url_regex, score=0.5)
url_recognizer = PatternRecognizer(supported_entity="URL_CUSTOM",
                                   patterns=[url_pattern])

registry = RecognizerRegistry()
registry.load_predefined_recognizers()
registry.add_recognizer(address_recognizer)
registry.add_recognizer(email_recognizer)
registry.add_recognizer(url_recognizer)

# %%
# Pass the parameters to AnalyzerEngine
analyzer = AnalyzerEngine(
    nlp_engine=nlp_engine, 
    supported_languages=["en"],
    registry=registry,
    context_aware_enhancer=LemmaContextAwareEnhancer(context_similarity_factor=0.8,
                                                     min_score_with_context_similarity=0.3))

# %%
analyzer_results = analyzer.analyze(train_df[0]['full_text'], language='en')
for res in analyzer_results:
    for i in range(2):
        print(train_df[i]['full_text'].replace('\n', ' ')[res.start:res.end])
        print(res)
        print('*' * 50)
# Out:
# commitment
# type: IN_PAN, start: 3315, end: 3325, score: 0.8500000000000001
# **************************************************
#
# type: IN_PAN, start: 3315, end: 3325, score: 0.8500000000000001
# **************************************************
# Nathalie Sylla
# type: PERSON, start: 52, end: 68, score: 0.85
# **************************************************
# tion Tool  Chall
# type: PERSON, start: 52, end: 68, score: 0.85
# **************************************************
# Buzan T.
# type: PERSON, start: 263, end: 271, score: 0.85
# **************************************************
# eeded.
# type: PERSON, start: 263, end: 271, score: 0.85
# **************************************************
# Buzan B.
# type: PERSON, start: 276, end: 284, score: 0.85
# **************************************************
#  learnin
# type: PERSON, start: 276, end: 284, score: 0.85
# **************************************************
# 1999
# type: DATE_TIME, start: 286, end: 290, score: 0.85
# **************************************************
# abou
# type: DATE_TIME, start: 286, end: 290, score: 0.85
# **************************************************
# Dessine-moi  l'intelligence
# type: PERSON, start: 292, end: 319, score: 0.85
# **************************************************
# design thinking in this cou
# type: PERSON, start: 292, end: 319, score: 0.85
# **************************************************
# Paris
# type: LOCATION, start: 321, end: 326, score: 0.85
# **************************************************
# e, we
# type: LOCATION, start: 321, end: 326, score: 0.85
# **************************************************
# Cf Annex1
# type: LOCATION, start: 533, end: 542, score: 0.85
# **************************************************
# ers.  Pre
# type: LOCATION, start: 533, end: 542, score: 0.85
# **************************************************
# two  hours
# type: DATE_TIME, start: 2201, end: 2211, score: 0.85
# **************************************************
# ed the  pr
# type: DATE_TIME, start: 2201, end: 2211, score: 0.85
# **************************************************
# Nathalie Sylla
# type: PERSON, start: 2281, end: 2295, score: 0.85
# **************************************************
# atisfaction. T
# type: PERSON, start: 2281, end: 2295, score: 0.85
# **************************************************
# two hours
# type: DATE_TIME, start: 2501, end: 2510, score: 0.85
# **************************************************
# th the he
# type: DATE_TIME, start: 2501, end: 2510, score: 0.85
# **************************************************
# Nathalie Sylla
# type: PERSON, start: 3648, end: 3662, score: 0.85
# **************************************************
#
# type: PERSON, start: 3648, end: 3662, score: 0.85
# **************************************************
# stakeholders
# type: US_DRIVER_LICENSE, start: 118, end: 130, score: 0.3
# **************************************************
# ime adapting
# type: US_DRIVER_LICENSE, start: 118, end: 130, score: 0.3
# **************************************************
# intelligence
# type: US_DRIVER_LICENSE, start: 307, end: 319, score: 0.3
# **************************************************
#  in this cou
# type: US_DRIVER_LICENSE, start: 307, end: 319, score: 0.3
# **************************************************
# Organisation
# type: US_DRIVER_LICENSE, start: 343, end: 355, score: 0.3
# **************************************************
#  it to solve
# type: US_DRIVER_LICENSE, start: 343, end: 355, score: 0.3
# **************************************************
# participants
# type: US_DRIVER_LICENSE, start: 1498, end: 1510, score: 0.3
# **************************************************
# up activity
# type: US_DRIVER_LICENSE, start: 1498, end: 1510, score: 0.3
# **************************************************
# stakeholders
# type: US_DRIVER_LICENSE, start: 1623, end: 1635, score: 0.3
# **************************************************
# lve the prob
# type: US_DRIVER_LICENSE, start: 1623, end: 1635, score: 0.3
# **************************************************
# stakeholders
# type: US_DRIVER_LICENSE, start: 1806, end: 1818, score: 0.3
# **************************************************
# volving: can
# type: US_DRIVER_LICENSE, start: 1806, end: 1818, score: 0.3
# **************************************************
# participants
# type: US_DRIVER_LICENSE, start: 2353, end: 2365, score: 0.3
# **************************************************
#  of people w
# type: US_DRIVER_LICENSE, start: 2353, end: 2365, score: 0.3
# **************************************************
# familiarized
# type: US_DRIVER_LICENSE, start: 2551, end: 2563, score: 0.3
# **************************************************
# olved in the
# type: US_DRIVER_LICENSE, start: 2551, end: 2563, score: 0.3
# **************************************************
# stakeholders
# type: US_DRIVER_LICENSE, start: 2577, end: 2589, score: 0.3
# **************************************************
# sentations,
# type: US_DRIVER_LICENSE, start: 2577, end: 2589, score: 0.3
# **************************************************
# constructive
# type: US_DRIVER_LICENSE, start: 2680, end: 2692, score: 0.3
# **************************************************
# learnt that
# type: US_DRIVER_LICENSE, start: 2680, end: 2692, score: 0.3
# **************************************************
# stakeholders
# type: US_DRIVER_LICENSE, start: 2716, end: 2728, score: 0.3
# **************************************************
#  can be diff
# type: US_DRIVER_LICENSE, start: 2716, end: 2728, score: 0.3
# **************************************************
# facilitation
# type: US_DRIVER_LICENSE, start: 3257, end: 3269, score: 0.3
# **************************************************
#
# type: US_DRIVER_LICENSE, start: 3257, end: 3269, score: 0.3
# **************************************************
# participants
# type: US_DRIVER_LICENSE, start: 3302, end: 3314, score: 0.3
# **************************************************
#
# type: US_DRIVER_LICENSE, start: 3302, end: 3314, score: 0.3
# **************************************************
# participants
# type: US_DRIVER_LICENSE, start: 3381, end: 3393, score: 0.3
# **************************************************
#
# type: US_DRIVER_LICENSE, start: 3381, end: 3393, score: 0.3
# **************************************************
# relationship
# type: US_DRIVER_LICENSE, start: 3514, end: 3526, score: 0.3
# **************************************************
#
# type: US_DRIVER_LICENSE, start: 3514, end: 3526, score: 0.3
# **************************************************
# facilitating
# type: US_DRIVER_LICENSE, start: 3543, end: 3555, score: 0.3
# **************************************************
#
# type: US_DRIVER_LICENSE, start: 3543, end: 3555, score: 0.3
# **************************************************
# innovation
# type: IN_PAN, start: 20, end: 30, score: 0.05
# **************************************************
# n Thinking
# type: IN_PAN, start: 20, end: 30, score: 0.05
# **************************************************
# reflexion-
# type: IN_PAN, start: 31, end: 41, score: 0.05
# **************************************************
# Assignment
# type: IN_PAN, start: 31, end: 41, score: 0.05
# **************************************************
# complexity
# type: IN_PAN, start: 161, end: 171, score: 0.05
# **************************************************
# ur bank. A
# type: IN_PAN, start: 161, end: 171, score: 0.05
# **************************************************
# definition
# type: IN_PAN, start: 249, end: 259, score: 0.05
# **************************************************
# pproach wa
# type: IN_PAN, start: 249, end: 259, score: 0.05
# **************************************************
# advantages
# type: IN_PAN, start: 563, end: 573, score: 0.05
# **************************************************
#  none of o
# type: IN_PAN, start: 563, end: 573, score: 0.05
# **************************************************
# accessible
# type: IN_PAN, start: 585, end: 595, score: 0.05
# **************************************************
#  seemed to
# type: IN_PAN, start: 585, end: 595, score: 0.05
# **************************************************
# investment
# type: IN_PAN, start: 645, end: 655, score: 0.05
# **************************************************
#  created a
# type: IN_PAN, start: 645, end: 655, score: 0.05
# **************************************************
# notetaking
# type: IN_PAN, start: 804, end: 814, score: 0.05
# **************************************************
# he prep ti
# type: IN_PAN, start: 804, end: 814, score: 0.05
# **************************************************
# encourages
# type: IN_PAN, start: 939, end: 949, score: 0.05
# **************************************************
# e solution
# type: IN_PAN, start: 939, end: 949, score: 0.05
# **************************************************
# creativity
# type: IN_PAN, start: 1399, end: 1409, score: 0.05
# **************************************************
# kboard to
# type: IN_PAN, start: 1399, end: 1409, score: 0.05
# **************************************************
# Creativity
# type: IN_PAN, start: 1467, end: 1477, score: 0.05
# **************************************************
# ific probl
# type: IN_PAN, start: 1467, end: 1477, score: 0.05
# **************************************************
# understand
# type: IN_PAN, start: 2047, end: 2057, score: 0.05
# **************************************************
# ask better
# type: IN_PAN, start: 2047, end: 2057, score: 0.05
# **************************************************
# innovation
# type: IN_PAN, start: 2249, end: 2259, score: 0.05
# **************************************************
# l as the c
# type: IN_PAN, start: 2249, end: 2259, score: 0.05
# **************************************************
# reflexion-
# type: IN_PAN, start: 2260, end: 2270, score: 0.05
# **************************************************
# stomer/sta
# type: IN_PAN, start: 2260, end: 2270, score: 0.05
# **************************************************
# innovation
# type: IN_PAN, start: 3616, end: 3626, score: 0.05
# **************************************************
#
# type: IN_PAN, start: 3616, end: 3626, score: 0.05
# **************************************************
# reflexion-
# type: IN_PAN, start: 3627, end: 3637, score: 0.05
# **************************************************
#
# type: IN_PAN, start: 3627, end: 3637, score: 0.05
# **************************************************

# %%
def tokens2index(row): 
    tokens = row['tokens']
    start_index = []
    end_index = []
    prev_index = 0
    
    for token in tokens:  
        start = prev_index + row['full_text'][prev_index:].index(token)
        end = start + len(token)
        start_index.append(start)
        end_index.append(end)
        prev_index = end
    return start_index, end_index

def search_position(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return low

def count_trailing_whitespaces(word):
    return len(word) - len(word.rstrip())

# %%
black_list = ["wiki", "coursera", ".pdf", ".PDF",
              "article", ".png", ".gov", ".work", ".ai",
              ".firm", ".arts", ".store", ".rec", ".travel",
              'miro', 'trello' '.edu']

# %%
NAME_STUDENT, URL_PERSONAL, EMAIL, STREET_ADDRESS, ID_NUM, USERNAME = [], [], [], [], [], []

preds = []
# Find the starting and ending position of each word after segmentation
for i in tqdm(range(len(test_df)), desc="Processing tokens2index"):
    start, end = tokens2index(test_df[i])
    # Add starting and ending position of each word into json
    test_df[i]['start'] = start
    test_df[i]['end'] = end
    
for i, d in tqdm(enumerate(test_df), total=len(test_df), desc="Analyzing entities"):
    results = analyzer.analyze(text=d['full_text'],
                               entities=[
                                         "PERSON", 
                                         "URL_CUSTOM",
                                         "EMAIL_ADDRESS",
                                         "EMAIL_CUSTOM", 
                                         "ADDRESS_CUSTOM",
                                         "US_SSN",
                                         "US_ITIN",
                                         "US_PASSPORT",
                                         "US_BANK_NUMBER",
                                         "USERNAME"],
                               language='en'
                              )
    pre_preds = []
    for r in results: 
        s = search_position(d['start'], r.start) 
        end = r.end 
        word = d['full_text'][r.start:r.end]
        end = end - count_trailing_whitespaces(word)
        temp_preds = [s]
        try:
            while d['end'][s+1] <= end:
                temp_preds.append(s+1)
                s += 1
        except:
            pass
        
        # Find out what the entity is, and give it the corresponding label
        tmp = False
        
        if r.entity_type == 'USERNAME':
            label =  'USERNAME'
            USERNAME.append(d['full_text'][r.start:r.end])
            
        if r.entity_type == 'PERSON':
            label =  'NAME_STUDENT'
            NAME_STUDENT.append(d['full_text'][r.start:r.end])
            
        if r.entity_type == 'ADDRESS_CUSTOM':
            label = 'STREET_ADDRESS'
            STREET_ADDRESS.append(d['full_text'][r.start:r.end])
            
        if r.entity_type == 'US_SSN' or r.entity_type == 'US_ITIN' or r.entity_type == 'US_PASSPORT' or r.entity_type == 'US_BANK_NUMBER':
            label = 'ID_NUM'
            ID_NUM.append(d['full_text'][r.start:r.end])
            
        if r.entity_type == 'EMAIL_ADDRESS' or r.entity_type == 'EMAIL_CUSTOM':
            label = 'EMAIL'
            EMAIL.append(d['full_text'][r.start:r.end])
            
        if r.entity_type == 'URL_CUSTOM':
            # Remove tags from blacklist
            for w in black_list:
                if w in word:
                    tmp = True
                    break
            
            label = 'URL_PERSONAL'
            URL_PERSONAL.append(d['full_text'][r.start:r.end])
            
        if tmp:
            continue
        
        for p in temp_preds:
            if len(pre_preds) > 0:
                if pre_preds[-1]['rlabel'] == r.entity_type and (p - pre_preds[-1]['token'] == 1):
                    label_f = "I-" + label # Middle position of an entity
                else:
                    label_f = "B-" + label # Otherwise the start of next entity
            else:
                label_f = "B-" + label
            pre_preds.append(({
                    "document": d['document'],
                    "token": p,
                    "label": label_f,
                    "rlabel": r.entity_type
                }))
    preds.extend(pre_preds)
# Out:
# Processing tokens2index: 100%|██████████| 10/10 [00:00<00:00, 666.11it/s]
# Analyzing entities: 100%|██████████| 10/10 [00:01<00:00,  5.02it/s]

# %%
submission = pd.DataFrame(preds).iloc[:, :-1].reset_index()
submission.columns = ['row_id','document', 'token', 'label']
submission.to_csv('submission.csv', index=False)
submission.head(50)
# Out:
#     row_id  document  token           label
# 0        0         7      9  B-NAME_STUDENT
# 1        1         7     10  I-NAME_STUDENT
# 2        2         7     52  B-NAME_STUDENT
# 3        3         7     53  I-NAME_STUDENT
# 4        4         7     55  B-NAME_STUDENT
# 5        5         7     56  I-NAME_STUDENT
# 6        6         7     60  B-NAME_STUDENT
# 7        7         7     61  I-NAME_STUDENT
# 8        8         7     62  I-NAME_STUDENT
# 9        9         7     63  I-NAME_STUDENT
# 10      10         7     64  I-NAME_STUDENT
# 11      11         7    482  B-NAME_STUDENT
# 12      12         7    483  I-NAME_STUDENT
# 13      13         7    741  B-NAME_STUDENT
# 14      14         7    742  I-NAME_STUDENT
# 15      15        10      0  B-NAME_STUDENT
# 16      16        10      1  I-NAME_STUDENT
# 17      17        10    464  B-NAME_STUDENT
# 18      18        10    465  I-NAME_STUDENT
# 19      19        16      4  B-NAME_STUDENT
# 20      20        16      5  I-NAME_STUDENT
# 21      21        20      5  B-NAME_STUDENT
# 22      22        20      6  I-NAME_STUDENT
# 23      23        20    328  B-NAME_STUDENT
# 24      24        20    330  B-NAME_STUDENT
# 25      25        56     12  B-NAME_STUDENT
# 26      26        56     13  I-NAME_STUDENT
# 27      27        86      6  B-NAME_STUDENT
# 28      28        86      7  I-NAME_STUDENT
# 29      29        86    137  B-NAME_STUDENT
# 30      30        93      0  B-NAME_STUDENT
# 31      31        93      1  I-NAME_STUDENT
# 32      32       104      8  B-NAME_STUDENT
# 33      33       104      9  I-NAME_STUDENT
# 34      34       112     28  B-NAME_STUDENT
# 35      35       112     29  I-NAME_STUDENT
# 36      36       112     30  I-NAME_STUDENT
# 37      37       123     32  B-NAME_STUDENT
# 38      38       123     33  I-NAME_STUDENT
# 39      39       123     34  I-NAME_STUDENT
# 40      40       123     35  I-NAME_STUDENT
# 41      41       123     38  B-NAME_STUDENT
# 42      42       123     65  B-NAME_STUDENT
# 43      43       123     66  I-NAME_STUDENT
# 44      44       123     99  B-NAME_STUDENT
# 45      45       123    100  I-NAME_STUDENT
# 46      46       123    101  I-NAME_STUDENT
# 47      47       123    102  I-NAME_STUDENT
# 48      48       123    133  B-NAME_STUDENT
# 49      49       123    223  B-NAME_STUDENT
